# %%
from mpl_toolkits.mplot3d import axes3d
from pylab import *
import matplotlib.pyplot as p1t
import matplotlib
import numpy as np
import time

# %%
xs = np.linspace(-1,1,50)
ys = np.linspace(-1,1,50)
zs= np.linspace(-1,1,50)
X,Y,Z= np. meshgrid(xs, ys,zs)
num=len(xs)

# %%
X.shape
# Out:
# (50, 50, 50)

# %%
APF=np.zeros(shape=(num,num,num))

for i in range(0,num):
    for j in range(0,num):
        for k in range(0,num):
            APF[i][j][k]=0.5*((X[i][j][k])**2+(Y[i][j][k])**2+(Z[i][j][k])**2)

# %%
gradAPF=np.gradient(APF,0.02,0.02,0.02,edge_order=1)

# %%
gradAPF_x=gradAPF[0]
gradAPF_y=gradAPF[1]
gradAPF_z=gradAPF[2]

# %%
slice=10
gradVector=np.zeros(shape=(10,10,10,3))

for x,xIdx in enumerate(np.arange(0,50)[::10]):
    for y,yIdx in enumerate(np.arange(0,50)[::10]):
        for z,zIdx in enumerate(np.arange(0,50)[::10]):
            gradVector[x][y][z][0]=gradAPF_x[xIdx][yIdx][zIdx]
            gradVector[x][y][z][1]=gradAPF_y[xIdx][yIdx][zIdx]
            gradVector[x][y][z][2]=gradAPF_z[xIdx][yIdx][zIdx]

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
slice=25
u=-gradAPF_x[::10,::10,::10]
v=-gradAPF_y[::10,::10,::10]
w=-gradAPF_z[::10,::10,::10]

x0=X[::10,::10,::10]
y0=Y[::10,::10,::10]
z0=Z[::10,::10,::10]

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)

ax.quiver(x0, y0, z0, u, v, w, length=0.1, color = 'black')

plt.show()

# %%
x0.shape
# Out:
# (1, 50, 50)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1, color = 'black')

plt.show()

# %%
u.shape
# Out:
# (9, 9, 3)
